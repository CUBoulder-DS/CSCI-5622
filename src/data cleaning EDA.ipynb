# %% [markdown]
# # Data Cleaning and EDA

# %%
#| include: false

# %matplotlib inline

import pandas as pd
from datetime import datetime
import numpy as np

from IPython.display import display, Latex, Markdown

import plotly.express as px
import plotly.io as pio
# Settings for plot rendering, makes work with HTML output + jupyer lab + static output
# pio.renderers.default = "notebook+plotly_mimetype+png"
pio.renderers.default = "plotly_mimetype+notebook_connected+png"

from ast import literal_eval

# %%
df_scraped = pd.read_csv("../data/scraped/scraped1_raw.csv", index_col=0)
df_scraped
# Out:
#                  type  position        asin
# 0      search_product         1  B0B8GTTK6V  \
# 1      search_product         2  B0CSVG1668
# 2      search_product         3  B09HF4LPR5
# 3      search_product         4  B0BDHT39HM
# 4      search_product         5  B0BHGJLX6W
# ...               ...       ...         ...
# 24964  search_product        12  B0CV7DF1MC
# 24965  search_product        13  B0CV7ZTT8Q
# 24966  search_product        14  B0CV7XC894
# 24967  search_product        15  B0CSFW92Q3
# 24968  search_product        16  B0CTX39YLJ
#
#                                                     name
# 0      AppleWatch Series 7 [GPS + Cellular 45mm] Smar...  \
# 1      AppleWatch Ultra 2 [GPS + Cellular 49mm] Smart...
# 2      AppleWatch Series 7 [GPS + Cellular 45mm] Smar...
# 3      AppleWatch Ultra [GPS + Cellular 49mm] Smart w...
# 4      AppleWatch Series 8 [GPS + Cellular 45mm] Smar...
# ...                                                  ...
# 24964  PUSOKEI Portable Monitor, 11.6 Inch 1080P FHD ...
# 24965  PUSOKEI Portable Monitor, 13.3 Inch 1080P FHD ...
# 24966  Yoidesu 10.5in 1920x1280 Full HD Portable Gami...
# 24967  FEELWORLD DH156 15.6inch Portable Monitor 1080...
# 24968  Computer Screen Shield Monitor Screen Screen P...
#
#                                                    image  has_prime
# 0      https://m.media-amazon.com/images/I/71zksDvWH-...      False  \
# 1      https://m.media-amazon.com/images/I/81k6R2uh1J...       True
# 2      https://m.media-amazon.com/images/I/91Kd2PB5Qs...       True
# 3      https://m.media-amazon.com/images/I/91jzT-Hi-T...       True
# 4      https://m.media-amazon.com/images/I/61lCtY1nWP...      False
# ...                                                  ...        ...
# 24964  https://m.media-amazon.com/images/I/51u58YcflH...      False
# 24965  https://m.media-amazon.com/images/I/616U44i2ha...      False
# 24966  https://m.media-amazon.com/images/I/61qU8np2VC...      False
# 24967  https://m.media-amazon.com/images/I/61orjMrisB...       True
# 24968  https://m.media-amazon.com/images/I/514JW-g-MR...      False
#
#        is_best_seller  is_amazon_choice  is_limited_deal  stars
# 0               False             False            False    5.0  \
# 1               False             False            False    NaN
# 2               False             False            False    4.6
# 3               False             False            False    4.3
# 4               False             False            False    4.6
# ...               ...               ...              ...    ...
# 24964           False             False            False    NaN
# 24965           False             False            False    NaN
# 24966           False             False            False    NaN
# 24967           False             False            False    NaN
# 24968           False             False            False    NaN
#
#        total_reviews                                                url
# 0                1.0  https://www.amazon.com/Apple-Cellular-Graphite...  \
# 1                NaN  https://www.amazon.com/Apple-Cellular-Smartwat...
# 2              433.0  https://www.amazon.com/Apple-Cellular-Graphite...
# 3               32.0  https://www.amazon.com/Apple-Cellular-Titanium...
# 4               95.0  https://www.amazon.com/Apple-Cellular-Graphite...
# ...              ...                                                ...
# 24964            NaN  https://www.amazon.com/PUSOKEI-Portable-Monito...
# 24965            NaN  https://www.amazon.com/PUSOKEI-Portable-Monito...
# 24966            NaN  https://www.amazon.com/Yoidesu-1920x1280-Porta...
# 24967            NaN  https://www.amazon.com/FEELWORLD-15-6inch-Port...
# 24968            NaN  https://www.amazon.com/Naroote-Computer-Protec...
#
#        availability_quantity spec price_string price_symbol   price
# 0                        1.0   {}      $878.00            $  878.00  \
# 1                        2.0   {}      $799.00            $  799.00
# 2                        1.0   {}      $799.00            $  799.00
# 3                        1.0   {}      $799.00            $  799.00
# 4                       12.0   {}      $791.98            $  791.98
# ...                      ...  ...          ...          ...     ...
# 24964                    NaN   {}      $154.89            $  154.89
# 24965                    NaN   {}      $162.19            $  162.19
# 24966                    NaN   {}      $109.19            $  109.19
# 24967                    7.0   {}      $169.99            $  169.99
# 24968                   13.0   {}       $61.28            $   61.28
#
#                                           original_price  section_name
# 0                                                    NaN           NaN
# 1                                                    NaN           NaN
# 2                                                    NaN           NaN
# 3                                                    NaN           NaN
# 4      {'price_string': '$828.00', 'price_symbol': '$...           NaN
# ...                                                  ...           ...
# 24964                                                NaN           NaN
# 24965                                                NaN           NaN
# 24966                                                NaN           NaN
# 24967                                                NaN           NaN
# 24968                                                NaN           NaN
#
# [24969 rows x 19 columns]

# %%
# Add `date_scraped` column
df_scraped["date_scraped"] = datetime(2024, 2, 1)

# Remove unecessary columns: 'type', 'position', 'has_prime', 'is_amazon_choice', 'is_limited_deal', 'availability_quantity', 'spec', 'price_string', 'price_symbol', 'section_name'
dropcols = ['type', 'position', 'has_prime', 'is_amazon_choice', 'is_limited_deal', 'availability_quantity', 'spec', 'price_string', 'price_symbol', 'section_name']
df_scraped = df_scraped.drop(dropcols, axis="columns", errors="ignore")

# Expand and fix original price
df_scraped["list_price"] = pd.json_normalize(df_scraped["original_price"].map(literal_eval, na_action="ignore"))["price"]
df_scraped["list_price"] = df_scraped["list_price"].fillna(df_scraped["price"])
df_scraped = df_scraped.drop("original_price", axis="columns", errors="ignore")

# Rename columns to match standard snake case for merging both datasets
df_scraped = df_scraped.rename(columns={"image": "image_url", "total_reviews": "reviews"})

# Drop rows with no asin or name or price
df_scraped = df_scraped.dropna(subset=["asin", "name", "price"])

# Fill NaN `reviews` column with 0
df_scraped["reviews"] = df_scraped["reviews"].fillna(0)

# Save cleaned df
df_scraped.to_csv("../data/scraped/scraped1.csv", index=False)

df_scraped
# Out:
#              asin                                               name
# 0      B0B8GTTK6V  AppleWatch Series 7 [GPS + Cellular 45mm] Smar...  \
# 1      B0CSVG1668  AppleWatch Ultra 2 [GPS + Cellular 49mm] Smart...
# 2      B09HF4LPR5  AppleWatch Series 7 [GPS + Cellular 45mm] Smar...
# 3      B0BDHT39HM  AppleWatch Ultra [GPS + Cellular 49mm] Smart w...
# 4      B0BHGJLX6W  AppleWatch Series 8 [GPS + Cellular 45mm] Smar...
# ...           ...                                                ...
# 24964  B0CV7DF1MC  PUSOKEI Portable Monitor, 11.6 Inch 1080P FHD ...
# 24965  B0CV7ZTT8Q  PUSOKEI Portable Monitor, 13.3 Inch 1080P FHD ...
# 24966  B0CV7XC894  Yoidesu 10.5in 1920x1280 Full HD Portable Gami...
# 24967  B0CSFW92Q3  FEELWORLD DH156 15.6inch Portable Monitor 1080...
# 24968  B0CTX39YLJ  Computer Screen Shield Monitor Screen Screen P...
#
#                                                image_url  is_best_seller
# 0      https://m.media-amazon.com/images/I/71zksDvWH-...           False  \
# 1      https://m.media-amazon.com/images/I/81k6R2uh1J...           False
# 2      https://m.media-amazon.com/images/I/91Kd2PB5Qs...           False
# 3      https://m.media-amazon.com/images/I/91jzT-Hi-T...           False
# 4      https://m.media-amazon.com/images/I/61lCtY1nWP...           False
# ...                                                  ...             ...
# 24964  https://m.media-amazon.com/images/I/51u58YcflH...           False
# 24965  https://m.media-amazon.com/images/I/616U44i2ha...           False
# 24966  https://m.media-amazon.com/images/I/61qU8np2VC...           False
# 24967  https://m.media-amazon.com/images/I/61orjMrisB...           False
# 24968  https://m.media-amazon.com/images/I/514JW-g-MR...           False
#
#        stars  reviews                                                url
# 0        5.0      1.0  https://www.amazon.com/Apple-Cellular-Graphite...  \
# 1        NaN      0.0  https://www.amazon.com/Apple-Cellular-Smartwat...
# 2        4.6    433.0  https://www.amazon.com/Apple-Cellular-Graphite...
# 3        4.3     32.0  https://www.amazon.com/Apple-Cellular-Titanium...
# 4        4.6     95.0  https://www.amazon.com/Apple-Cellular-Graphite...
# ...      ...      ...                                                ...
# 24964    NaN      0.0  https://www.amazon.com/PUSOKEI-Portable-Monito...
# 24965    NaN      0.0  https://www.amazon.com/PUSOKEI-Portable-Monito...
# 24966    NaN      0.0  https://www.amazon.com/Yoidesu-1920x1280-Porta...
# 24967    NaN      0.0  https://www.amazon.com/FEELWORLD-15-6inch-Port...
# 24968    NaN      0.0  https://www.amazon.com/Naroote-Computer-Protec...
#
#         price date_scraped  list_price
# 0      878.00   2024-02-01      878.00
# 1      799.00   2024-02-01      799.00
# 2      799.00   2024-02-01      799.00
# 3      799.00   2024-02-01      799.00
# 4      791.98   2024-02-01      828.00
# ...       ...          ...         ...
# 24964  154.89   2024-02-01      154.89
# 24965  162.19   2024-02-01      162.19
# 24966  109.19   2024-02-01      109.19
# 24967  169.99   2024-02-01      169.99
# 24968   61.28   2024-02-01       61.28
#
# [21517 rows x 10 columns]

# %%
df_scraped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21517 entries, 0 to 24968
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   asin            21517 non-null  object
#  1   name            21517 non-null  object
#  2   image_url       21517 non-null  object
#  3   is_best_seller  21517 non-null  bool
#  4   stars           14525 non-null  float64
#  5   reviews         21517 non-null  float64
#  6   url             21517 non-null  object
#  7   price           21517 non-null  float64
#  8   date_scraped    21517 non-null  datetime64[ns]
#  9   list_price      21517 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(4), object(4)
# memory usage: 1.7+ MB

# %%
df_ksept = pd.read_csv("../data/kaggle_asaniczka/amazon_products.csv")
df_ksept_cats = pd.read_csv("../data/kaggle_asaniczka/amazon_categories.csv")

# %%
df_ksept
# Out:
#                asin                                              title
# 0        B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...  \
# 1        B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2        B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# 3        B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# 4        B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
# ...             ...                                                ...
# 1426332  B00R3LIKCO  American Flag Patriotic USA Classic 5 Panel Me...
# 1426333  B098BQ7ZQ3  Men's Baseball Cap - H2O-DRI Line Up Curved Br...
# 1426334  B07X1MVNT1  [4 Pack] Adjustable Eyeglasses and Sunglasses ...
# 1426335  B08XLBG8V9                          Ax2002 Aviator Sunglasses
# 1426336  B07GH67QC8  in Hoc Signo Vinces Knights Templar Masonic Em...
#
#                                                     imgUrl
# 0        https://m.media-amazon.com/images/I/815dLQKYIY...  \
# 1        https://m.media-amazon.com/images/I/81bQlm7vf6...
# 2        https://m.media-amazon.com/images/I/71EA35zvJB...
# 3        https://m.media-amazon.com/images/I/91k6NYLQyI...
# 4        https://m.media-amazon.com/images/I/61NJoaZcP9...
# ...                                                    ...
# 1426332  https://m.media-amazon.com/images/I/71PDJFz6AA...
# 1426333  https://m.media-amazon.com/images/I/812Tycexs4...
# 1426334  https://m.media-amazon.com/images/I/61vvYW1S9J...
# 1426335  https://m.media-amazon.com/images/I/51+yjD4F1x...
# 1426336  https://m.media-amazon.com/images/I/91Kt2KQf0E...
#
#                                    productURL  stars  reviews   price
# 0        https://www.amazon.com/dp/B014TMV5YE    4.5        0  139.99  \
# 1        https://www.amazon.com/dp/B07GDLCQXV    4.5        0  169.99
# 2        https://www.amazon.com/dp/B07XSCCZYG    4.6        0  365.49
# 3        https://www.amazon.com/dp/B08MVFKGJM    4.6        0  291.59
# 4        https://www.amazon.com/dp/B01DJLKZBA    4.5        0  174.99
# ...                                       ...    ...      ...     ...
# 1426332  https://www.amazon.com/dp/B00R3LIKCO    4.2        0   14.95
# 1426333  https://www.amazon.com/dp/B098BQ7ZQ3    4.4        0   33.99
# 1426334  https://www.amazon.com/dp/B07X1MVNT1    3.6        0    8.54
# 1426335  https://www.amazon.com/dp/B08XLBG8V9    4.5        0   54.36
# 1426336  https://www.amazon.com/dp/B07GH67QC8    4.9        0   18.79
#
#          listPrice  category_id  isBestSeller  boughtInLastMonth
# 0             0.00          104         False               2000
# 1           209.99          104         False               1000
# 2           429.99          104         False                300
# 3           354.37          104         False                400
# 4           309.99          104         False                400
# ...            ...          ...           ...                ...
# 1426332       0.00          112         False                  0
# 1426333       0.00          112         False                  0
# 1426334       0.00          112         False                  0
# 1426335      57.39          112         False                  0
# 1426336       0.00          112         False                  0
#
# [1426337 rows x 11 columns]

# %%
# Add `date_scraped` column
df_ksept["date_scraped"] = datetime(2023, 11, 1)

# Remove unecessary columns `boughtInLastMonth`
df_ksept = df_ksept.drop("boughtInLastMonth", axis="columns", errors="ignore")

# Drop rows with any NaNs
df_ksept = df_ksept.dropna(subset=["title"])

# Fix list_price 0 to be instead equal to `price`
df_ksept["listPrice"] = df_ksept["listPrice"].replace(0.0, np.NaN).fillna(df_ksept["price"])

# Change category_id to actual category by using category table
df_ksept["category"] = df_ksept["category_id"].replace(to_replace=df_ksept_cats["id"].tolist(), value=df_ksept_cats["category_name"].tolist()).astype("category")
df_ksept = df_ksept.drop("category_id", axis="columns")

# Rename columns to match standard snake case for merging both datasets
df_ksept = df_ksept.rename(columns={"title": "name", "imgUrl": "image_url", "productURL": "url", "listPrice": "list_price", "isBestSeller": "is_best_seller"})

df_ksept
# Out:
#                asin                                               name
# 0        B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...  \
# 1        B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2        B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# 3        B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# 4        B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
# ...             ...                                                ...
# 1426332  B00R3LIKCO  American Flag Patriotic USA Classic 5 Panel Me...
# 1426333  B098BQ7ZQ3  Men's Baseball Cap - H2O-DRI Line Up Curved Br...
# 1426334  B07X1MVNT1  [4 Pack] Adjustable Eyeglasses and Sunglasses ...
# 1426335  B08XLBG8V9                          Ax2002 Aviator Sunglasses
# 1426336  B07GH67QC8  in Hoc Signo Vinces Knights Templar Masonic Em...
#
#                                                  image_url
# 0        https://m.media-amazon.com/images/I/815dLQKYIY...  \
# 1        https://m.media-amazon.com/images/I/81bQlm7vf6...
# 2        https://m.media-amazon.com/images/I/71EA35zvJB...
# 3        https://m.media-amazon.com/images/I/91k6NYLQyI...
# 4        https://m.media-amazon.com/images/I/61NJoaZcP9...
# ...                                                    ...
# 1426332  https://m.media-amazon.com/images/I/71PDJFz6AA...
# 1426333  https://m.media-amazon.com/images/I/812Tycexs4...
# 1426334  https://m.media-amazon.com/images/I/61vvYW1S9J...
# 1426335  https://m.media-amazon.com/images/I/51+yjD4F1x...
# 1426336  https://m.media-amazon.com/images/I/91Kt2KQf0E...
#
#                                           url  stars  reviews   price
# 0        https://www.amazon.com/dp/B014TMV5YE    4.5        0  139.99  \
# 1        https://www.amazon.com/dp/B07GDLCQXV    4.5        0  169.99
# 2        https://www.amazon.com/dp/B07XSCCZYG    4.6        0  365.49
# 3        https://www.amazon.com/dp/B08MVFKGJM    4.6        0  291.59
# 4        https://www.amazon.com/dp/B01DJLKZBA    4.5        0  174.99
# ...                                       ...    ...      ...     ...
# 1426332  https://www.amazon.com/dp/B00R3LIKCO    4.2        0   14.95
# 1426333  https://www.amazon.com/dp/B098BQ7ZQ3    4.4        0   33.99
# 1426334  https://www.amazon.com/dp/B07X1MVNT1    3.6        0    8.54
# 1426335  https://www.amazon.com/dp/B08XLBG8V9    4.5        0   54.36
# 1426336  https://www.amazon.com/dp/B07GH67QC8    4.9        0   18.79
#
#          list_price  is_best_seller date_scraped           category
# 0            139.99           False   2023-11-01          Suitcases
# 1            209.99           False   2023-11-01          Suitcases
# 2            429.99           False   2023-11-01          Suitcases
# 3            354.37           False   2023-11-01          Suitcases
# 4            309.99           False   2023-11-01          Suitcases
# ...             ...             ...          ...                ...
# 1426332       14.95           False   2023-11-01  Men's Accessories
# 1426333       33.99           False   2023-11-01  Men's Accessories
# 1426334        8.54           False   2023-11-01  Men's Accessories
# 1426335       57.39           False   2023-11-01  Men's Accessories
# 1426336       18.79           False   2023-11-01  Men's Accessories
#
# [1426336 rows x 11 columns]

# %%
df_ksept.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1426336 entries, 0 to 1426336
# Data columns (total 11 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   asin            1426336 non-null  object
#  1   name            1426336 non-null  object
#  2   image_url       1426336 non-null  object
#  3   url             1426336 non-null  object
#  4   stars           1426336 non-null  float64
#  5   reviews         1426336 non-null  int64
#  6   price           1426336 non-null  float64
#  7   list_price      1426336 non-null  float64
#  8   is_best_seller  1426336 non-null  bool
#  9   date_scraped    1426336 non-null  datetime64[ns]
#  10  category        1426336 non-null  category
# dtypes: bool(1), category(1), datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 112.9+ MB

# %%
# Save cleaned df
df_ksept.to_csv("../data/kaggle_asaniczka/amazon_products_cleaned.csv", index=False)

# %%
df_az = pd.concat([df_scraped, df_ksept], ignore_index=True)

# Remove duplicates (by asin + date scraped)
df_az = df_az.drop_duplicates(subset=["asin", "date_scraped"])

# Rename columns
df_az.columns = df_az.columns.map(lambda x : x.replace("_", " ")).str.title()

df_az
# Out:
#                Asin                                               Name
# 0        B0B8GTTK6V  AppleWatch Series 7 [GPS + Cellular 45mm] Smar...  \
# 1        B0CSVG1668  AppleWatch Ultra 2 [GPS + Cellular 49mm] Smart...
# 2        B09HF4LPR5  AppleWatch Series 7 [GPS + Cellular 45mm] Smar...
# 3        B0BDHT39HM  AppleWatch Ultra [GPS + Cellular 49mm] Smart w...
# 4        B0BHGJLX6W  AppleWatch Series 8 [GPS + Cellular 45mm] Smar...
# ...             ...                                                ...
# 1447848  B00R3LIKCO  American Flag Patriotic USA Classic 5 Panel Me...
# 1447849  B098BQ7ZQ3  Men's Baseball Cap - H2O-DRI Line Up Curved Br...
# 1447850  B07X1MVNT1  [4 Pack] Adjustable Eyeglasses and Sunglasses ...
# 1447851  B08XLBG8V9                          Ax2002 Aviator Sunglasses
# 1447852  B07GH67QC8  in Hoc Signo Vinces Knights Templar Masonic Em...
#
#                                                  Image Url  Is Best Seller
# 0        https://m.media-amazon.com/images/I/71zksDvWH-...           False  \
# 1        https://m.media-amazon.com/images/I/81k6R2uh1J...           False
# 2        https://m.media-amazon.com/images/I/91Kd2PB5Qs...           False
# 3        https://m.media-amazon.com/images/I/91jzT-Hi-T...           False
# 4        https://m.media-amazon.com/images/I/61lCtY1nWP...           False
# ...                                                    ...             ...
# 1447848  https://m.media-amazon.com/images/I/71PDJFz6AA...           False
# 1447849  https://m.media-amazon.com/images/I/812Tycexs4...           False
# 1447850  https://m.media-amazon.com/images/I/61vvYW1S9J...           False
# 1447851  https://m.media-amazon.com/images/I/51+yjD4F1x...           False
# 1447852  https://m.media-amazon.com/images/I/91Kt2KQf0E...           False
#
#          Stars  Reviews                                                Url
# 0          5.0      1.0  https://www.amazon.com/Apple-Cellular-Graphite...  \
# 1          NaN      0.0  https://www.amazon.com/Apple-Cellular-Smartwat...
# 2          4.6    433.0  https://www.amazon.com/Apple-Cellular-Graphite...
# 3          4.3     32.0  https://www.amazon.com/Apple-Cellular-Titanium...
# 4          4.6     95.0  https://www.amazon.com/Apple-Cellular-Graphite...
# ...        ...      ...                                                ...
# 1447848    4.2      0.0               https://www.amazon.com/dp/B00R3LIKCO
# 1447849    4.4      0.0               https://www.amazon.com/dp/B098BQ7ZQ3
# 1447850    3.6      0.0               https://www.amazon.com/dp/B07X1MVNT1
# 1447851    4.5      0.0               https://www.amazon.com/dp/B08XLBG8V9
# 1447852    4.9      0.0               https://www.amazon.com/dp/B07GH67QC8
#
#           Price Date Scraped  List Price           Category
# 0        878.00   2024-02-01      878.00                NaN
# 1        799.00   2024-02-01      799.00                NaN
# 2        799.00   2024-02-01      799.00                NaN
# 3        799.00   2024-02-01      799.00                NaN
# 4        791.98   2024-02-01      828.00                NaN
# ...         ...          ...         ...                ...
# 1447848   14.95   2023-11-01       14.95  Men's Accessories
# 1447849   33.99   2023-11-01       33.99  Men's Accessories
# 1447850    8.54   2023-11-01        8.54  Men's Accessories
# 1447851   54.36   2023-11-01       57.39  Men's Accessories
# 1447852   18.79   2023-11-01       18.79  Men's Accessories
#
# [1444082 rows x 11 columns]

# %%
# Save cleaned df
df_az.to_csv("../data/products_cleaned.csv", index=False)

# %%
df_az[df_az["Asin"].duplicated(keep=False)].sort_values(by="Asin")
# Out:
#               Asin                                               Name
# 20414   B00003IEM9        Energizer MAX Alkaline Batteries AAA 2 Pack  \
# 718579  B00003IEM9        Energizer MAX Alkaline Batteries AAA 2 Pack
# 556358  B00005IBX9  Cuisinart DCC-1200P1 Brew Central 12-Cup Progr...
# 6340    B00005IBX9  Cuisinart DCC-1200P1 Brew Central 12-Cup Progr...
# 20456   B00008XPN0  Energizer MAX AAA Batteries (12 Pack), Triple ...
# ...            ...                                                ...
# 15448   B0CJCHDKLF  Wireless Earbuds Bluetooth Headphones, 40H Pla...
# 222493  B0CJKVT223  MSI Pro MP251, 25", IPS, 1920 x 1080 (FHD), 10...
# 11922   B0CJKVT223  MSI PRO MP251 24.5-inch IPS 1920 x 1080 (FHD) ...
# 949581  BT00CTP2GM  Amazon.com Gift Card in a Greeting Card (Vario...
# 7896    BT00CTP2GM  Amazon.com Gift Card in a Greeting Card (Vario...
#
#                                                 Image Url  Is Best Seller
# 20414   https://m.media-amazon.com/images/I/81ZAKiZk7h...           False  \
# 718579  https://m.media-amazon.com/images/I/81ZAKiZk7h...           False
# 556358  https://m.media-amazon.com/images/I/61-qv4WD-j...           False
# 6340    https://m.media-amazon.com/images/I/61sZMasBgR...           False
# 20456   https://m.media-amazon.com/images/I/71NKUau16V...           False
# ...                                                   ...             ...
# 15448   https://m.media-amazon.com/images/I/61IOFpeimn...           False
# 222493  https://m.media-amazon.com/images/I/81vm74fzYN...           False
# 11922   https://m.media-amazon.com/images/I/81vm74fzYN...           False
# 949581  https://m.media-amazon.com/images/I/71AnOa2lFQ...           False
# 7896    https://m.media-amazon.com/images/I/71AnOa2lFQ...           False
#
#         Stars  Reviews                                                Url
# 20414     4.7    845.0  https://www.amazon.com/Energizer-MAX-Alkaline-...  \
# 718579    4.7      0.0               https://www.amazon.com/dp/B00003IEM9
# 556358    4.6      0.0               https://www.amazon.com/dp/B00005IBX9
# 6340      4.6  12339.0  https://www.amazon.com/Cuisinart-DCC-1200-Cent...
# 20456     4.8   7185.0  https://www.amazon.com/Energizer-Max-Alkaline-...
# ...       ...      ...                                                ...
# 15448     4.8   2624.0  https://www.amazon.com/YAQ-Bluetooth-Headphone...
# 222493    0.0      0.0               https://www.amazon.com/dp/B0CJKVT223
# 11922     4.5    261.0  https://www.amazon.com/MSI-MP251-24-5-inch-Ada...
# 949581    4.8      0.0               https://www.amazon.com/dp/BT00CTP2GM
# 7896      4.8  13975.0  https://www.amazon.com/Amazon-com-Greeting-Bir...
#
#          Price Date Scraped  List Price            Category
# 20414     3.25   2024-02-01        3.25                 NaN
# 718579    3.27   2023-11-01        3.27  Household Supplies
# 556358   97.00   2023-11-01       97.00     Home Appliances
# 6340     99.95   2024-02-01       99.95                 NaN
# 20456     9.45   2024-02-01       13.99                 NaN
# ...        ...          ...         ...                 ...
# 15448    21.99   2024-02-01       79.99                 NaN
# 222493  119.99   2023-11-01      119.99   Computer Monitors
# 11922    79.99   2024-02-01      119.99                 NaN
# 949581   15.00   2023-11-01       15.00          Gift Cards
# 7896     15.00   2024-02-01       15.00                 NaN
#
# [5170 rows x 11 columns]
